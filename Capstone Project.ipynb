# %% [markdown]
# # Capstone Project

# %% [markdown]
# # Introduction
# As a new Residential Developer that just entered the industry, we are ready to take up the challenge to find the optimal place to build a residential building.
#
# An optimal residential apartment/building will be a place that has high demands in dwelling. It is highly likely that it is close to large shopping malls, in a large city and have high population.
#
# In this scenario we want to find out where exactly in Australian cities to start developing a residential area.
#
# This will be achieved by using publicly available data about Australia cities and their neighbourhoods so we can employ various forms of data analytics and visualizations to help us in our search.

# %% [markdown]
# # Data
#
# Data that will be used to find out the optimal locations are Wikipedia to find the largest cities and extract the populations and other (if needed) population and demographics data.
#
# Name and location of neighbourhoods in each suburban area will be obtained by a combination of Google Maps API geocoding and the Postal code information per city.Also the number of shopping malls and their location in every neighborhood will be obtained using the Foursquare API.

# %% [markdown]
# ### Import all necessary libraries

# %%
import pandas as pd
import numpy as np

import requests
# !pip install BeautifulSoup4
import bs4
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

# !conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')
# Out:
# Requirement already satisfied: BeautifulSoup4 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (4.9.1)
# Requirement already satisfied: soupsieve>1.2 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from BeautifulSoup4) (2.0.1)
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
# Libraries imported.

# %% [markdown]
# Web scrapping population information from Wikipedia to determine which city in Australia has the largest population.
# Larger population would indicate we have better potential in the demands of residential dwelling.

# %%
response = requests.get('https://en.wikipedia.org/wiki/Template:Largest_cities_of_Australia')
html = bs4.BeautifulSoup(response.text, 'html.parser')
table = html.find('table',{'class':'navbox'})

# %%
#scrape the wikipedia table for its entries and combine those in the dataframe.
city_data = []
cycle_i = 0
cycle_j = 0
for i in table.findAll('tr'):
    row_data=[]
    if cycle_i <2: #skip some empty rows
        cycle_i += 1
        continue
    for j in i.findAll('td'):
        if cycle_i == 2 and (cycle_j == 0 or cycle_j == 9): #some image subscript is in the table that we can skip as well
            cycle_j += 1
            continue
        row_data.append(j.text.strip())
        cycle_j += 1
    cycle_i += 1
    city_data.append(row_data)
df =pd.DataFrame(city_data)

# %% [markdown]
# Tidy up the web scraped results into one single data frame.

# %%
df1 = df.iloc[:,0:4].reset_index(drop=True).dropna()
df2 = df.iloc[:,4::].reset_index(drop=True).dropna()

# %%
df1.columns=['0','1','2','3']
df2.columns=['0','1','2','3']

# %% [markdown]
# sort the rows of cities by their population size

# %%
df = df1.append(df2,sort=True)
df.columns = ['index','City','Region','Population']

# %%
df.head()
# Out:
#   index       City Region Population
# 0     1     Sydney    NSW  5,312,163
# 1     2  Melbourne    Vic  5,078,193
# 2     3   Brisbane    Qld  2,514,184
# 3     4      Perth     WA  2,085,973
# 4     5   Adelaide     SA  1,359,760

# %% [markdown]
# We can clearly see here that Sydney has the largest population base, hence we will select Sydney as our city to investigate which exact area/location to develop our new resitential area.
# the following analysis will be based on Sydney.

# %% [markdown]
# Find the geographical coordinate of Sydney Australia.

# %%
address = 'Sydney, New South Wales, Australia'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Australia are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Australia are -33.8548157, 151.2164539.

# %% [markdown]
# With access of Foursquare API we will grab the information for all the locations for the stores in Sydney.
# This is based on our previous research proving that buyers tend to take into consideration of the accessibility to shopping malls.

# %%
search_query = 'Store'
radius = 20000
print(search_query + ' .... OK!')
# Out:
# Store .... OK!

# %% [markdown]
# Initiate credentials

# %%
CLIENT_ID = 'VVIN1Z3IDBJEH3ZK5O2EJFLM2ZT2RURS1OCBC51CPOOSG5HQ' # your Foursquare ID
CLIENT_SECRET = '2UJYDUAAW1KIK03VHJ1I0MWSC22RM340FMITJTLMLFW50JEK' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# Your credentails:
# CLIENT_ID: VVIN1Z3IDBJEH3ZK5O2EJFLM2ZT2RURS1OCBC51CPOOSG5HQ
# CLIENT_SECRET:2UJYDUAAW1KIK03VHJ1I0MWSC22RM340FMITJTLMLFW50JEK
# 'https://api.foursquare.com/v2/venues/search?client_id=VVIN1Z3IDBJEH3ZK5O2EJFLM2ZT2RURS1OCBC51CPOOSG5HQ&client_secret=2UJYDUAAW1KIK03VHJ1I0MWSC22RM340FMITJTLMLFW50JEK&ll=-33.8548157,151.2164539&v=20180604&query=Store&radius=20000&limit=30'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5f005cbda10064683ee035cf'},
#  'response': {'venues': [{'id': '4b4aa8d7f964a5206d8c26e3',
#     'name': 'The Fine Food Store',
#     'location': {'address': 'Shop 9, The Rocks Centre, Kendall Ln',
#      'lat': -33.85854612519328,
#      'lng': 151.20863306088074,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -33.85854612519328,
#        'lng': 151.20863306088074}],
#      'distance': 833,
#      'postalCode': '2000',
#      'cc': 'AU',
#      'city': 'The Rocks',
#      'state': 'NSW',
#      'country': 'Australia',
#      'formattedAddress': ['Shop 9, The Rocks Centre, Kendall Ln',
#       'The Rocks NSW 2000',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593859315',
#     'hasPerk': False},
#    {'id': '4be3dd30fe299521f5a3966c',
#     'name': 'Bridgepoint Convenience Store',
#     'location': {'address': '38 Bridge St',
#      'lat': -33.863446988260556,
#      'lng': 151.21074219264634,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -33.863446988260556,
#        'lng': 151.21074219264634}],
#      'distance': 1096,
#      'postalCode': '2000',
#      'cc': 'AU',
#      'city': 'Sydney',
#      'state': 'NSW',
#      'country': 'Australia',
#      'formattedAddress': ['38 Bridge St', 'Sydney NSW 2000', 'Australia']},
#     'categories': [{'id': '4d954b0ea243a5684a65b473',
#       'name': 'Convenience Store',
#       'pluralName': 'Convenience Stores',
#       'shortName': 'Convenience Store',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/conveniencestore_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593859315',
#     'hasPerk': False},
#    {'id': '5dd666940726a400074a8bbc',
#     'name': 'Glue Store Darling Harbour',
#     'location': {'address': 'Shop 412 Harbourside 2 - 10 Darling Drive',
#      'lat': -33.85521688689388,
#      'lng': 151.21619582176208,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -33.85521688689388,
#        'lng': 151.21619582176208}],
#      'distance': 50,
#      'postalCode': '2000',
#      'cc': 'AU',
#      'city': 'Darling Harbour',
#      'state': 'NSW',
#      'country': 'Australia',
#      'formattedAddress': ['Shop 412 Harbourside 2 - 10 Darling Drive',
#       'Darling Harbour NSW 2000',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d103951735',
#       'name': 'Clothing Store',
#       'pluralName': 'Clothing Stores',
#       'shortName': 'Apparel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593859315',
#     'hasPerk': False},
#    {'id': '4cf3286f94feb1f7846a21ba',
#     'name': 'City Convenience Store',
#     'location': {'address': "Shop 22, 1 O'Connell St",
#      'crossStreet': 'The Wintergarden',
#      'lat': -33.864513694683396,
#      'lng': 151.20995700359344,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -33.864513694683396,
#        'lng': 151.20995700359344}],
#      'distance': 1235,
#      'postalCode': '2000',
#      'cc': 'AU',
#      'neighborhood': 'Sydney City Center',
#      'city': 'Sydney',
#      'state': 'NSW',
#      'country': 'Australia',
#      'formattedAddress': ["Shop 22, 1 O'Connell St (The Wintergarden)",
#       'Sydney NSW 2000',
#       'Australia']},
#     'categories': [{'id': '4d954b0ea243a5684a65b473',
#       'name': 'Convenience Store',
#       'pluralName': 'Convenience Stores',
#       'shortName': 'Convenience Store',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/conveniencestore_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593859315',
#     'hasPerk': False},
#    {'id': '4c8f69b7b3bcb60cee2e6127',
#     'name': 'The Rock Store',
#     'location': {'address': '21 Kent Street',
#      'lat': -33.85859,
#      'lng': 151.20331,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -33.85859,
#        'lng': 151.20331}],
#      'distance': 1285,
#      'postalCode': '2000',
#      'cc': 'AU',
#      'city': 'Millers Point',
#      'state': 'NSW',
#      'country': 'Australia',
#      'formattedAddress': ['21 Kent Street',
#       'Millers Point NSW 2000',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d130941735',
#       'name': 'Building',
#       'pluralName': 'Buildings',
#       'shortName': 'Building',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593859315',
#     'hasPerk': False},
#    {'id': '4ef9a08029c268318b4f9b9f',
#     'name': 'Hayes General Store',
#     'location': {'address': 'Shop 3, 1 Hayes St',
#      'lat': -33.84187,
#      'lng': 151.21904,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -33.84187,
#        'lng': 151.21904}],
#      'distance': 1460,
#      'postalCode': '2089',
#      'cc': 'AU',
#      'city': 'Neutral Bay',
#      'state': 'NSW',
#      'country': 'Australia',
#      'formattedAddress': ['Shop 3, 1 Hayes St',
#       'Neutral Bay NSW 2089',
#       'Australia']},
#     'categories': [{'id': '4d954b0ea243a5684a65b473',
#       'name': 'Convenience Store',
#       'pluralName': 'Convenience Stores',
#       'shortName': 'Convenience Store',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/conveniencestore_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593859315',
#     'hasPerk': False},
#    {'id': '5849f527109dfe7d5c04303f',
#     'name': 'Collector Store',
#     'location': {'lat': -33.865029,
#      'lng': 151.20245,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -33.865029,
#        'lng': 151.20245}],
#      'distance': 1722,
#      'postalCode': '2000',
#      'cc': 'AU',
#      'neighborhood': 'Barangaroo, NSW',
#      'city': 'Sydney',
#      'state': 'NSW',
#      'country': 'Australia',
#      'formattedAddress': ['Sydney NSW 2000', 'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d128951735',
#       'name': 'Gift Shop',
#       'pluralName': 'Gift Shops',
#       'shortName': 'Gift Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/giftshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593859315',
#     'hasPerk': False},
#    {'id': '4cd0c4e77f56a1430389d0a6',
#     'name': 'That Store',
#     'location': {'address': 'Westfield Sydney',
#      'lat': -33.869312,
#      'lng': 151.209,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -33.869312,
#        'lng': 151.209}],
#      'distance': 1754,
#      'cc': 'AU',
#      'country': 'Australia',
#      'formattedAddress': ['Westfield Sydney', 'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d103951735',
#       'name': 'Clothing Store',
#       'pluralName': 'Clothing Stores',
#       'shortName': 'Apparel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593859315',
#     'hasPerk': False},
#    {'id': '4f878174e4b02c4175697ec6',
#     'name': 'Design Tshirts Store Graniph',
#     'location': {'address': 'Shop 1001D, Westfield Sydney, 188 Pitt St',
#      'lat': -33.869986,
#      'lng': 151.209026,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -33.869986,
#        'lng': 151.209026}],
#      'distance': 1822,
#      'postalCode': '2000',
#      'cc': 'AU',
#      'city': 'Sydney',
#      'state': 'NSW',
#      'country': 'Australia',
#      'formattedAddress': ['Shop 1001D, Westfield Sydney, 188 Pitt St',
#       'Sydney NSW 2000',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d103951735',
#       'name': 'Clothing Store',
#       'pluralName': 'Clothing Stores',
#       'shortName': 'Apparel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '112832665'},
#     'referralId': 'v-1593859315',
#     'hasPerk': False},
#    {'id': '4f1cc6f0e4b07befff5c27f6',
#     'name': 'Oxford Store',
#     'location': {'address': 'Greenwood Shopping Centre',
#      'lat': -33.839895719001696,
#      'lng': 151.20776543545992,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -33.839895719001696,
#        'lng': 151.20776543545992}],
#      'distance': 1844,
#      'postalCode': '2060',
#      'cc': 'AU',
#      'city': 'North Sydney',
#      'state': 'NSW',
#      'country': 'Australia',
#      'formattedAddress': ['Greenwood Shopping Centre',
#       'North Sydney NSW 2060',
#       'Australia']},
#     'categories': [],
#     'referralId': 'v-1593859315',
#     'hasPerk': False},
#    {'id': '4ec4b5e15c5c09569b66c7a7',
#     'name': 'The Bose Store',
#     'location': {'address': 'Westfield Sydney',
#      'crossStreet': '188 Pitt St.',
#      'lat': -33.87032863944357,
#      'lng': 151.20940644178754,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -33.87032863944357,
#        'lng': 151.20940644178754}],
#      'distance': 1845,
#      'postalCode': '2000',
#      'cc': 'AU',
#      'city': 'Sydney',
#      'state': 'NSW',
#      'country': 'Australia',
#      'formattedAddress': ['Westfield Sydney (188 Pitt St.)',
#       'Sydney NSW 2000',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d122951735',
#       'name': 'Electronics Store',
#       'pluralName': 'Electronics Stores',
#       'shortName': 'Electronics',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/technology_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593859315',
#     'hasPerk': False},
#    {'id': '4cc8d9a04650a35d0a388b1e',
#     'name': 'Superdry Store',
#     'location': {'address': '188 Pitt St',
#      'crossStreet': 'Lvl 1 Shop 1008, Westfield',
#      'lat': -33.870522985056915,
#      'lng': 151.2088712442553,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -33.870522985056915,
#        'lng': 151.2088712442553}],
#      'distance': 1883,
#      'postalCode': '2000',
#      'cc': 'AU',
#      'city': 'Sydney',
#      'state': 'NSW',
#      'country': 'Australia',
#      'formattedAddress': ['188 Pitt St (Lvl 1 Shop 1008, Westfield)',
#       'Sydney NSW 2000',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d103951735',
#       'name': 'Clothing Store',
#       'pluralName': 'Clothing Stores',
#       'shortName': 'Apparel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593859315',
#     'hasPerk': False},
#    {'id': '4b590c0bf964a5200d7a28e3',
#     'name': 'Metropolitan Museum of Art Store',
#     'location': {'address': 'QVB, 455 George St.',
#      'lat': -33.871467,
#      'lng': 151.206779,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -33.871467,
#        'lng': 151.206779}],
#      'distance': 2058,
#      'postalCode': '2000',
#      'cc': 'AU',
#      'city': 'Sydney',
#      'state': 'NSW',
#      'country': 'Australia',
#      'formattedAddress': ['QVB, 455 George St.',
#       'Sydney NSW 2000',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d127951735',
#       'name': 'Arts & Crafts Store',
#       'pluralName': 'Arts & Crafts Stores',
#       'shortName': 'Arts & Crafts',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/artstore_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593859315',
#     'hasPerk': False},
#    {'id': '4cc9319cd54fa1cd14013629',
#     'name': 'Optus Store',
#     'location': {'address': 'Westfield Sydney',
#      'crossStreet': 'Pitt St. Mall',
#      'lat': -33.87195123667039,
#      'lng': 151.2075548448143,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -33.87195123667039,
#        'lng': 151.2075548448143}],
#      'distance': 2077,
#      'postalCode': '2000',
#      'cc': 'AU',
#      'city': 'Sydney',
#      'state': 'NSW',
#      'country': 'Australia',
#      'formattedAddress': ['Westfield Sydney (Pitt St. Mall)',
#       'Sydney NSW 2000',
#       'Australia']},
#     'categories': [{'id': '4f04afc02fb6e1c99f3db0bc',
#       'name': 'Mobile Phone Shop',
#       'pluralName': 'Mobile Phone Shops',
#       'shortName': 'Mobile Phones',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mobilephoneshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593859315',
#     'hasPerk': False},
#    {'id': '4c3e644f8d99b71354d51a06',
#     'name': 'G-Star RAW Store',
#     'location': {'address': '684-686 George Street, Shop 101',
#      'lat': -33.8768491,
#      'lng': 151.2063863,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -33.8768491,
#        'lng': 151.2063863}],
#      'distance': 2623,
#      'postalCode': '2000',
#      'cc': 'AU',
#      'city': 'Sydney',
#      'state': 'NSW',
#      'country': 'Australia',
#      'formattedAddress': ['684-686 George Street, Shop 101',
#       'Sydney NSW 2000',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d103951735',
#       'name': 'Clothing Store',
#       'pluralName': 'Clothing Stores',
#       'shortName': 'Apparel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593859315',
#     'hasPerk': False},
#    {'id': '4da057b9bb206ea8cb1fd9fd',
#     'name': 'General Store Of Contemporary Art',
#     'location': {'address': '77-83 William St',
#      'lat': -33.8755528093896,
#      'lng': 151.21527858218627,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -33.8755528093896,
#        'lng': 151.21527858218627}],
#      'distance': 2310,
#      'cc': 'AU',
#      'city': 'Woolloomooloo',
#      'state': 'NSW',
#      'country': 'Australia',
#      'formattedAddress': ['77-83 William St',
#       'Woolloomooloo NSW',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d1e2931735',
#       'name': 'Art Gallery',
#       'pluralName': 'Art Galleries',
#       'shortName': 'Art Gallery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/artgallery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593859315',
#     'hasPerk': False},
#    {'id': '4b677f8bf964a5207e522be3',
#     'name': 'Millennium Towers Convenience Store',
#     'location': {'address': 'Millenium Towers',
#      'crossStreet': '289-295 Sussex St.',
#      'lat': -33.874155280267225,
#      'lng': 151.20429157939503,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -33.874155280267225,
#        'lng': 151.20429157939503}],
#      'distance': 2428,
#      'postalCode': '2000',
#      'cc': 'AU',
#      'city': 'Sydney',
#      'state': 'NSW',
#      'country': 'Australia',
#      'formattedAddress': ['Millenium Towers (289-295 Sussex St.)',
#       'Sydney NSW 2000',
#       'Australia']},
#     'categories': [{'id': '4d954b0ea243a5684a65b473',
#       'name': 'Convenience Store',
#       'pluralName': 'Convenience Stores',
#       'shortName': 'Convenience Store',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/conveniencestore_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593859315',
#     'hasPerk': False},
#    {'id': '4be3f46f21d5a593c0411a11',
#     'name': 'The Record Store',
#     'location': {'address': '255B Crown Street',
#      'lat': -33.87986,
#      'lng': 151.21481,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -33.87986,
#        'lng': 151.21481}],
#      'distance': 2792,
#      'postalCode': '2010',
#      'cc': 'AU',
#      'city': 'Darlinghurst',
#      'state': 'NSW',
#      'country': 'Australia',
#      'formattedAddress': ['255B Crown Street',
#       'Darlinghurst NSW 2010',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d10d951735',
#       'name': 'Record Shop',
#       'pluralName': 'Record Shops',
#       'shortName': 'Record Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/record_shop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593859315',
#     'hasPerk': False},
#    {'id': '4b56b071f964a520a51828e3',
#     'name': 'Corner Convenience Store',
#     'location': {'address': '82-84 Stanley St',
#      'lat': -33.87585590629045,
#      'lng': 151.2157282439311,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -33.87585590629045,
#        'lng': 151.2157282439311}],
#      'distance': 2343,
#      'postalCode': '2010',
#      'cc': 'AU',
#      'city': 'Darlinghurst',
#      'state': 'NSW',
#      'country': 'Australia',
#      'formattedAddress': ['82-84 Stanley St',
#       'Darlinghurst NSW 2010',
#       'Australia']},
#     'categories': [{'id': '4d954b0ea243a5684a65b473',
#       'name': 'Convenience Store',
#       'pluralName': 'Convenience Stores',
#       'shortName': 'Convenience Store',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/conveniencestore_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593859315',
#     'hasPerk': False},
#    {'id': '4cfc4ef02d80a143b79950d8',
#     'name': 'City Convenience Store',
#     'location': {'lat': -33.876839459936,
#      'lng': 151.21065681642204,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -33.876839459936,
#        'lng': 151.21065681642204}],
#      'distance': 2509,
#      'cc': 'AU',
#      'country': 'Australia',
#      'formattedAddress': ['Australia']},
#     'categories': [{'id': '4d954b0ea243a5684a65b473',
#       'name': 'Convenience Store',
#       'pluralName': 'Convenience Stores',
#       'shortName': 'Convenience Store',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/conveniencestore_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593859315',
#     'hasPerk': False},
#    {'id': '4b667678f964a520f0212be3',
#     'name': 'Sussex Convenience Store',
#     'location': {'address': '368 Sussex St',
#      'lat': -33.87628765335874,
#      'lng': 151.20465164068608,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -33.87628765335874,
#        'lng': 151.20465164068608}],
#      'distance': 2627,
#      'postalCode': '2000',
#      'cc': 'AU',
#      'city': 'Sydney',
#      'state': 'NSW',
#      'country': 'Australia',
#      'formattedAddress': ['368 Sussex St', 'Sydney NSW 2000', 'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d1ff941735',
#       'name': 'Miscellaneous Shop',
#       'pluralName': 'Miscellaneous Shops',
#       'shortName': 'Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593859315',
#     'hasPerk': False},
#    {'id': '52800bd611d2515793c6bc80',
#     'name': 'Telstra Store',
#     'location': {'address': '231 Elizabeth Street',
#      'lat': -33.877316,
#      'lng': 151.213475,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -33.877316,
#        'lng': 151.213475}],
#      'distance': 2519,
#      'postalCode': '2009',
#      'cc': 'AU',
#      'city': 'Sydney',
#      'state': 'NSW',
#      'country': 'Australia',
#      'formattedAddress': ['231 Elizabeth Street',
#       'Sydney NSW 2009',
#       'Australia']},
#     'categories': [{'id': '4f04afc02fb6e1c99f3db0bc',
#       'name': 'Mobile Phone Shop',
#       'pluralName': 'Mobile Phone Shops',
#       'shortName': 'Mobile Phones',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mobilephoneshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593859315',
#     'hasPerk': False},
#    {'id': '4b39a894f964a5205b5e25e3',
#     'name': 'Supply Basement Store',
#     'location': {'address': '20 Burton St.',
#      'lat': -33.878231,
#      'lng': 151.214502,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -33.878231,
#        'lng': 151.214502}],
#      'distance': 2612,
#      'postalCode': '2010',
#      'cc': 'AU',
#      'city': 'Darlinghurst',
#      'state': 'NSW',
#      'country': 'Australia',
#      'formattedAddress': ['20 Burton St.',
#       'Darlinghurst NSW 2010',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d107951735',
#       'name': 'Shoe Store',
#       'pluralName': 'Shoe Stores',
#       'shortName': 'Shoes',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_shoestore_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593859315',
#     'hasPerk': False},
#    {'id': '4bbd7a83a8cf76b0ede3b1fd',
#     'name': 'Pyrmont Convenience Store',
#     'location': {'address': 'Shop 2, 14 Bunn Street',
#      'crossStreet': 'nr Pyrmont St',
#      'lat': -33.871119292233615,
#      'lng': 151.19634747505185,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -33.871119292233615,
#        'lng': 151.19634747505185}],
#      'distance': 2597,
#      'postalCode': '2009',
#      'cc': 'AU',
#      'city': 'Pyrmont',
#      'state': 'NSW',
#      'country': 'Australia',
#      'formattedAddress': ['Shop 2, 14 Bunn Street (nr Pyrmont St)',
#       'Pyrmont NSW 2009',
#       'Australia']},
#     'categories': [{'id': '4d954b0ea243a5684a65b473',
#       'name': 'Convenience Store',
#       'pluralName': 'Convenience Stores',
#       'shortName': 'Convenience Store',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/conveniencestore_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593859315',
#     'hasPerk': False},
#    {'id': '4c42f6c2ce54e21e03620d1a',
#     'name': 'City Convenience Store',
#     'location': {'address': 'Wentworth St.',
#      'crossStreet': 'Goulburn St.',
#      'lat': -33.879199961859044,
#      'lng': 151.20970060585333,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -33.879199961859044,
#        'lng': 151.20970060585333}],
#      'distance': 2785,
#      'postalCode': '2000',
#      'cc': 'AU',
#      'city': 'Sydney',
#      'state': 'NSW',
#      'country': 'Australia',
#      'formattedAddress': ['Wentworth St. (Goulburn St.)',
#       'Sydney NSW 2000',
#       'Australia']},
#     'categories': [{'id': '4d954b0ea243a5684a65b473',
#       'name': 'Convenience Store',
#       'pluralName': 'Convenience Stores',
#       'shortName': 'Convenience Store',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/conveniencestore_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593859315',
#     'hasPerk': False},
#    {'id': '4e37e340d164374eb68ab2cc',
#     'name': 'Convenience Store at the Boundary',
#     'location': {'address': 'Boundary St',
#      'crossStreet': 'nr Liverpool St',
#      'lat': -33.879472533333335,
#      'lng': 151.22369,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -33.879472533333335,
#        'lng': 151.22369}],
#      'distance': 2825,
#      'postalCode': '2021',
#      'cc': 'AU',
#      'city': 'Paddington',
#      'state': 'NSW',
#      'country': 'Australia',
#      'formattedAddress': ['Boundary St (nr Liverpool St)',
#       'Paddington NSW 2021',
#       'Australia']},
#     'categories': [{'id': '4d954b0ea243a5684a65b473',
#       'name': 'Convenience Store',
#       'pluralName': 'Convenience Stores',
#       'shortName': 'Convenience Store',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/conveniencestore_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593859315',
#     'hasPerk': False},
#    {'id': '536db26b498e4279315682fe',
#     'name': 'MCA Store',
#     'location': {'lat': -33.85989848941257,
#      'lng': 151.2092794196959,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -33.85989848941257,
#        'lng': 151.2092794196959}],
#      'distance': 871,
#      'cc': 'AU',
#      'country': 'Australia',
#      'formattedAddress': ['Australia']},
#     'categories': [{'id': '4bf58dd8d48988d114951735',
#       'name': 'Bookstore',
#       'pluralName': 'Bookstores',
#       'shortName': 'Bookstore',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bookstore_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593859315',
#     'hasPerk': False},
#    {'id': '4bbaa8951261d13a56f2ea98',
#     'name': 'Nike Store',
#     'location': {'address': '197 Military Rd.',
#      'lat': -33.831518,
#      'lng': 151.223313,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -33.831518,
#        'lng': 151.223313}],
#      'distance': 2669,
#      'postalCode': '2090',
#      'cc': 'AU',
#      'city': 'Neutral Bay',
#      'state': 'NSW',
#      'country': 'Australia',
#      'formattedAddress': ['197 Military Rd.',
#       'Neutral Bay NSW 2090',
#       'Australia']},
#     'categories': [{'id': '4bf58dd8d48988d1f2941735',
#       'name': 'Sporting Goods Shop',
#       'pluralName': 'Sporting Goods Shops',
#       'shortName': 'Sporting Goods',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/sports_outdoors_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593859315',
#     'hasPerk': False},
#    {'id': '4bd4df7a637ba5933ca9f570',
#     'name': 'The Village Store',
#     'location': {'address': '2 Mitchell Rd',
#      'lat': -33.87093653,
#      'lng': 151.238385,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -33.87093653,
#        'lng': 151.238385}],
#      'distance': 2707,
#      'postalCode': '2027',
#      'cc': 'AU',
#      'city': 'Darling Point',
#      'state': 'NSW',
#      'country': 'Australia',
#      'formattedAddress': ['2 Mitchell Rd',
#       'Darling Point NSW 2027',
#       'Australia']},
#     'categories': [{'id': '4d954b0ea243a5684a65b473',
#       'name': 'Convenience Store',
#       'pluralName': 'Convenience Stores',
#       'shortName': 'Convenience Store',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/conveniencestore_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593859315',
#     'hasPerk': False},
#    {'id': '5a20d9d4780eee2046af3f56',
#     'name': 'The Digital Store Australia Limited',
#     'location': {'address': '35 Foster Street',
#      'lat': -33.8805627,
#      'lng': 151.209456,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -33.8805627,
#        'lng': 151.209456}],
#      'distance': 2938,
#      'postalCode': '2010',
#      'cc': 'AU',
#      'city': 'Surry Hills',
#      'state': 'NSW',
#      'country': 'Australia',
#      'formattedAddress': ['35 Foster Street',
#       'Surry Hills NSW 2010',
#       'Australia']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b36',
#       'name': 'IT Services',
#       'pluralName': 'IT Services',
#       'shortName': 'IT Services',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/technology_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1593859315',
#     'hasPerk': False}]}}

# %% [markdown]
# We will transform the JSON data into dataframe for ease of analysis

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:5: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """
#                          id                           name  \
# 0  4b4aa8d7f964a5206d8c26e3            The Fine Food Store
# 1  4be3dd30fe299521f5a3966c  Bridgepoint Convenience Store
# 2  5dd666940726a400074a8bbc     Glue Store Darling Harbour
# 3  4cf3286f94feb1f7846a21ba         City Convenience Store
# 4  4c8f69b7b3bcb60cee2e6127                 The Rock Store
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...  v-1593859315    False
# 1  [{'id': '4d954b0ea243a5684a65b473', 'name': 'C...  v-1593859315    False
# 2  [{'id': '4bf58dd8d48988d103951735', 'name': 'C...  v-1593859315    False
# 3  [{'id': '4d954b0ea243a5684a65b473', 'name': 'C...  v-1593859315    False
# 4  [{'id': '4bf58dd8d48988d130941735', 'name': 'B...  v-1593859315    False
#
#                             location.address  location.lat  location.lng  \
# 0       Shop 9, The Rocks Centre, Kendall Ln    -33.858546    151.208633
# 1                               38 Bridge St    -33.863447    151.210742
# 2  Shop 412 Harbourside 2 - 10 Darling Drive    -33.855217    151.216196
# 3                    Shop 22, 1 O'Connell St    -33.864514    151.209957
# 4                             21 Kent Street    -33.858590    151.203310
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': -33.8585461251932...                833
# 1  [{'label': 'display', 'lat': -33.8634469882605...               1096
# 2  [{'label': 'display', 'lat': -33.8552168868938...                 50
# 3  [{'label': 'display', 'lat': -33.8645136946833...               1235
# 4  [{'label': 'display', 'lat': -33.85859, 'lng':...               1285
#
#   location.postalCode location.cc    location.city location.state  \
# 0                2000          AU        The Rocks            NSW
# 1                2000          AU           Sydney            NSW
# 2                2000          AU  Darling Harbour            NSW
# 3                2000          AU           Sydney            NSW
# 4                2000          AU    Millers Point            NSW
#
#   location.country                          location.formattedAddress  \
# 0        Australia  [Shop 9, The Rocks Centre, Kendall Ln, The Roc...
# 1        Australia         [38 Bridge St, Sydney NSW 2000, Australia]
# 2        Australia  [Shop 412 Harbourside 2 - 10 Darling Drive, Da...
# 3        Australia  [Shop 22, 1 O'Connell St (The Wintergarden), S...
# 4        Australia  [21 Kent Street, Millers Point NSW 2000, Austr...
#
#   location.crossStreet location.neighborhood venuePage.id
# 0                  NaN                   NaN          NaN
# 1                  NaN                   NaN          NaN
# 2                  NaN                   NaN          NaN
# 3     The Wintergarden    Sydney City Center          NaN
# 4                  NaN                   NaN          NaN

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                    name           categories  \
# 0                   The Fine Food Store                 Café
# 1         Bridgepoint Convenience Store    Convenience Store
# 2            Glue Store Darling Harbour       Clothing Store
# 3                City Convenience Store    Convenience Store
# 4                        The Rock Store             Building
# 5                   Hayes General Store    Convenience Store
# 6                       Collector Store            Gift Shop
# 7                            That Store       Clothing Store
# 8          Design Tshirts Store Graniph       Clothing Store
# 9                          Oxford Store                 None
# 10                       The Bose Store    Electronics Store
# 11                       Superdry Store       Clothing Store
# 12     Metropolitan Museum of Art Store  Arts & Crafts Store
# 13                          Optus Store    Mobile Phone Shop
# 14                     G-Star RAW Store       Clothing Store
# 15    General Store Of Contemporary Art          Art Gallery
# 16  Millennium Towers Convenience Store    Convenience Store
# 17                     The Record Store          Record Shop
# 18             Corner Convenience Store    Convenience Store
# 19               City Convenience Store    Convenience Store
# 20             Sussex Convenience Store   Miscellaneous Shop
# 21                        Telstra Store    Mobile Phone Shop
# 22                Supply Basement Store           Shoe Store
# 23            Pyrmont Convenience Store    Convenience Store
# 24               City Convenience Store    Convenience Store
# 25    Convenience Store at the Boundary    Convenience Store
# 26                            MCA Store            Bookstore
# 27                           Nike Store  Sporting Goods Shop
# 28                    The Village Store    Convenience Store
# 29  The Digital Store Australia Limited          IT Services
#
#                                       address        lat         lng  \
# 0        Shop 9, The Rocks Centre, Kendall Ln -33.858546  151.208633
# 1                                38 Bridge St -33.863447  151.210742
# 2   Shop 412 Harbourside 2 - 10 Darling Drive -33.855217  151.216196
# 3                     Shop 22, 1 O'Connell St -33.864514  151.209957
# 4                              21 Kent Street -33.858590  151.203310
# 5                          Shop 3, 1 Hayes St -33.841870  151.219040
# 6                                         NaN -33.865029  151.202450
# 7                            Westfield Sydney -33.869312  151.209000
# 8   Shop 1001D, Westfield Sydney, 188 Pitt St -33.869986  151.209026
# 9                   Greenwood Shopping Centre -33.839896  151.207765
# 10                           Westfield Sydney -33.870329  151.209406
# 11                                188 Pitt St -33.870523  151.208871
# 12                        QVB, 455 George St. -33.871467  151.206779
# 13                           Westfield Sydney -33.871951  151.207555
# 14            684-686 George Street, Shop 101 -33.876849  151.206386
# 15                           77-83 William St -33.875553  151.215279
# 16                           Millenium Towers -33.874155  151.204292
# 17                          255B Crown Street -33.879860  151.214810
# 18                           82-84 Stanley St -33.875856  151.215728
# 19                                        NaN -33.876839  151.210657
# 20                              368 Sussex St -33.876288  151.204652
# 21                       231 Elizabeth Street -33.877316  151.213475
# 22                              20 Burton St. -33.878231  151.214502
# 23                     Shop 2, 14 Bunn Street -33.871119  151.196347
# 24                              Wentworth St. -33.879200  151.209701
# 25                                Boundary St -33.879473  151.223690
# 26                                        NaN -33.859898  151.209279
# 27                           197 Military Rd. -33.831518  151.223313
# 28                              2 Mitchell Rd -33.870937  151.238385
# 29                           35 Foster Street -33.880563  151.209456
#
#                                        labeledLatLngs  distance postalCode  \
# 0   [{'label': 'display', 'lat': -33.8585461251932...       833       2000
# 1   [{'label': 'display', 'lat': -33.8634469882605...      1096       2000
# 2   [{'label': 'display', 'lat': -33.8552168868938...        50       2000
# 3   [{'label': 'display', 'lat': -33.8645136946833...      1235       2000
# 4   [{'label': 'display', 'lat': -33.85859, 'lng':...      1285       2000
# 5   [{'label': 'display', 'lat': -33.84187, 'lng':...      1460       2089
# 6   [{'label': 'display', 'lat': -33.865029, 'lng'...      1722       2000
# 7   [{'label': 'display', 'lat': -33.869312, 'lng'...      1754        NaN
# 8   [{'label': 'display', 'lat': -33.869986, 'lng'...      1822       2000
# 9   [{'label': 'display', 'lat': -33.8398957190016...      1844       2060
# 10  [{'label': 'display', 'lat': -33.8703286394435...      1845       2000
# 11  [{'label': 'display', 'lat': -33.8705229850569...      1883       2000
# 12  [{'label': 'display', 'lat': -33.871467, 'lng'...      2058       2000
# 13  [{'label': 'display', 'lat': -33.8719512366703...      2077       2000
# 14  [{'label': 'display', 'lat': -33.8768491, 'lng...      2623       2000
# 15  [{'label': 'display', 'lat': -33.8755528093896...      2310        NaN
# 16  [{'label': 'display', 'lat': -33.8741552802672...      2428       2000
# 17  [{'label': 'display', 'lat': -33.87986, 'lng':...      2792       2010
# 18  [{'label': 'display', 'lat': -33.8758559062904...      2343       2010
# 19  [{'label': 'display', 'lat': -33.876839459936,...      2509        NaN
# 20  [{'label': 'display', 'lat': -33.8762876533587...      2627       2000
# 21  [{'label': 'display', 'lat': -33.877316, 'lng'...      2519       2009
# 22  [{'label': 'display', 'lat': -33.878231, 'lng'...      2612       2010
# 23  [{'label': 'display', 'lat': -33.8711192922336...      2597       2009
# 24  [{'label': 'display', 'lat': -33.8791999618590...      2785       2000
# 25  [{'label': 'display', 'lat': -33.8794725333333...      2825       2021
# 26  [{'label': 'display', 'lat': -33.8598984894125...       871        NaN
# 27  [{'label': 'display', 'lat': -33.831518, 'lng'...      2669       2090
# 28  [{'label': 'display', 'lat': -33.87093653, 'ln...      2707       2027
# 29  [{'label': 'display', 'lat': -33.8805627, 'lng...      2938       2010
#
#     cc             city state    country  \
# 0   AU        The Rocks   NSW  Australia
# 1   AU           Sydney   NSW  Australia
# 2   AU  Darling Harbour   NSW  Australia
# 3   AU           Sydney   NSW  Australia
# 4   AU    Millers Point   NSW  Australia
# 5   AU      Neutral Bay   NSW  Australia
# 6   AU           Sydney   NSW  Australia
# 7   AU              NaN   NaN  Australia
# 8   AU           Sydney   NSW  Australia
# 9   AU     North Sydney   NSW  Australia
# 10  AU           Sydney   NSW  Australia
# 11  AU           Sydney   NSW  Australia
# 12  AU           Sydney   NSW  Australia
# 13  AU           Sydney   NSW  Australia
# 14  AU           Sydney   NSW  Australia
# 15  AU    Woolloomooloo   NSW  Australia
# 16  AU           Sydney   NSW  Australia
# 17  AU     Darlinghurst   NSW  Australia
# 18  AU     Darlinghurst   NSW  Australia
# 19  AU              NaN   NaN  Australia
# 20  AU           Sydney   NSW  Australia
# 21  AU           Sydney   NSW  Australia
# 22  AU     Darlinghurst   NSW  Australia
# 23  AU          Pyrmont   NSW  Australia
# 24  AU           Sydney   NSW  Australia
# 25  AU       Paddington   NSW  Australia
# 26  AU              NaN   NaN  Australia
# 27  AU      Neutral Bay   NSW  Australia
# 28  AU    Darling Point   NSW  Australia
# 29  AU      Surry Hills   NSW  Australia
#
#                                      formattedAddress  \
# 0   [Shop 9, The Rocks Centre, Kendall Ln, The Roc...
# 1          [38 Bridge St, Sydney NSW 2000, Australia]
# 2   [Shop 412 Harbourside 2 - 10 Darling Drive, Da...
# 3   [Shop 22, 1 O'Connell St (The Wintergarden), S...
# 4   [21 Kent Street, Millers Point NSW 2000, Austr...
# 5   [Shop 3, 1 Hayes St, Neutral Bay NSW 2089, Aus...
# 6                        [Sydney NSW 2000, Australia]
# 7                       [Westfield Sydney, Australia]
# 8   [Shop 1001D, Westfield Sydney, 188 Pitt St, Sy...
# 9   [Greenwood Shopping Centre, North Sydney NSW 2...
# 10  [Westfield Sydney (188 Pitt St.), Sydney NSW 2...
# 11  [188 Pitt St (Lvl 1 Shop 1008, Westfield), Syd...
# 12  [QVB, 455 George St., Sydney NSW 2000, Australia]
# 13  [Westfield Sydney (Pitt St. Mall), Sydney NSW ...
# 14  [684-686 George Street, Shop 101, Sydney NSW 2...
# 15   [77-83 William St, Woolloomooloo NSW, Australia]
# 16  [Millenium Towers (289-295 Sussex St.), Sydney...
# 17  [255B Crown Street, Darlinghurst NSW 2010, Aus...
# 18  [82-84 Stanley St, Darlinghurst NSW 2010, Aust...
# 19                                        [Australia]
# 20        [368 Sussex St, Sydney NSW 2000, Australia]
# 21  [231 Elizabeth Street, Sydney NSW 2009, Austra...
# 22  [20 Burton St., Darlinghurst NSW 2010, Australia]
# 23  [Shop 2, 14 Bunn Street (nr Pyrmont St), Pyrmo...
# 24  [Wentworth St. (Goulburn St.), Sydney NSW 2000...
# 25  [Boundary St (nr Liverpool St), Paddington NSW...
# 26                                        [Australia]
# 27  [197 Military Rd., Neutral Bay NSW 2090, Austr...
# 28  [2 Mitchell Rd, Darling Point NSW 2027, Austra...
# 29  [35 Foster Street, Surry Hills NSW 2010, Austr...
#
#                    crossStreet        neighborhood                        id
# 0                          NaN                 NaN  4b4aa8d7f964a5206d8c26e3
# 1                          NaN                 NaN  4be3dd30fe299521f5a3966c
# 2                          NaN                 NaN  5dd666940726a400074a8bbc
# 3             The Wintergarden  Sydney City Center  4cf3286f94feb1f7846a21ba
# 4                          NaN                 NaN  4c8f69b7b3bcb60cee2e6127
# 5                          NaN                 NaN  4ef9a08029c268318b4f9b9f
# 6                          NaN     Barangaroo, NSW  5849f527109dfe7d5c04303f
# 7                          NaN                 NaN  4cd0c4e77f56a1430389d0a6
# 8                          NaN                 NaN  4f878174e4b02c4175697ec6
# 9                          NaN                 NaN  4f1cc6f0e4b07befff5c27f6
# 10                188 Pitt St.                 NaN  4ec4b5e15c5c09569b66c7a7
# 11  Lvl 1 Shop 1008, Westfield                 NaN  4cc8d9a04650a35d0a388b1e
# 12                         NaN                 NaN  4b590c0bf964a5200d7a28e3
# 13               Pitt St. Mall                 NaN  4cc9319cd54fa1cd14013629
# 14                         NaN                 NaN  4c3e644f8d99b71354d51a06
# 15                         NaN                 NaN  4da057b9bb206ea8cb1fd9fd
# 16          289-295 Sussex St.                 NaN  4b677f8bf964a5207e522be3
# 17                         NaN                 NaN  4be3f46f21d5a593c0411a11
# 18                         NaN                 NaN  4b56b071f964a520a51828e3
# 19                         NaN                 NaN  4cfc4ef02d80a143b79950d8
# 20                         NaN                 NaN  4b667678f964a520f0212be3
# 21                         NaN                 NaN  52800bd611d2515793c6bc80
# 22                         NaN                 NaN  4b39a894f964a5205b5e25e3
# 23               nr Pyrmont St                 NaN  4bbd7a83a8cf76b0ede3b1fd
# 24                Goulburn St.                 NaN  4c42f6c2ce54e21e03620d1a
# 25             nr Liverpool St                 NaN  4e37e340d164374eb68ab2cc
# 26                         NaN                 NaN  536db26b498e4279315682fe
# 27                         NaN                 NaN  4bbaa8951261d13a56f2ea98
# 28                         NaN                 NaN  4bd4df7a637ba5933ca9f570
# 29                         NaN                 NaN  5a20d9d4780eee2046af3f56

# %% [markdown]
# Let's visualize the all the stores that are in city of Sydney

# %%
dataframe_filtered.name
# Out:
# 0                     The Fine Food Store
# 1           Bridgepoint Convenience Store
# 2              Glue Store Darling Harbour
# 3                  City Convenience Store
# 4                          The Rock Store
# 5                     Hayes General Store
# 6                         Collector Store
# 7                              That Store
# 8            Design Tshirts Store Graniph
# 9                            Oxford Store
# 10                         The Bose Store
# 11                         Superdry Store
# 12       Metropolitan Museum of Art Store
# 13                            Optus Store
# 14                       G-Star RAW Store
# 15      General Store Of Contemporary Art
# 16    Millennium Towers Convenience Store
# 17                       The Record Store
# 18               Corner Convenience Store
# 19                 City Convenience Store
# 20               Sussex Convenience Store
# 21                          Telstra Store
# 22                  Supply Basement Store
# 23              Pyrmont Convenience Store
# 24                 City Convenience Store
# 25      Convenience Store at the Boundary
# 26                              MCA Store
# 27                             Nike Store
# 28                      The Village Store
# 29    The Digital Store Australia Limited
# Name: name, dtype: object

# %% [markdown]
# Visualising this on a map

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel

# add a red circle marker to represent city centre
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Conrad Hotel',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Centres as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Conclusion

# %% [markdown]
# From the map it is not hard to identify where the clusters of stores are in the city of Sydney.
# The plotted blue dots on the map are the positions of all the stores, we can see they form a cluster in the South of Sydney, which is surrounded by the suburbs such as Haymarket and Millers Point.
# Therefore, as a new developer we would choose to find an area of empty space in the lower(South) Shore that has close proximity to the stores as an investment for residential area.
